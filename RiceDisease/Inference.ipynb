# %%
import sys
sys.path.append(r'../HelperFunctions')

# %%
import DataHelper as dh
import AugHelper as ah
import InferenceHelper as ih
import ModelConfigHelper as mch

# %%
path_info = dh.getFileDirectory(fetchType='file')
path_info
# Out:
# Please enter the root directory of the file path -> C:\Users\user\Desktop\ML\PyTorch\Hackathon\RiceLeaf\Dataset\Rice Leaf Disease Images\Rice Leaf Disease Images\Blast\BLAST1_001.jpg
# {'path': 'C:\\Users\\user\\Desktop\\ML\\PyTorch\\Hackathon\\RiceLeaf\\Dataset\\Rice Leaf Disease Images\\Rice Leaf Disease Images\\Blast\\BLAST1_001.jpg',
#  'type': 'file'}

# %%
img = ih.getTestImg(path=path_info['path'])
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x28667CCCB50>

# %%
weights = 'RiceModelWeights.pth'
dictlabel = ['Bacterialblight', 'Blast', 'Brownspot', 'Tungro']

# %%
imgTransform = ah.getImageTransform(227)

# %%
model = mch.getCustomizedPreTrainedModel('alexnet',len(dictlabel),feature_extract=False,preTrained=False)

# %%
ih.inference(img_path=path_info['path'],model=model,weight_path=weights,dictlabel=dictlabel,transform=imgTransform,softmax=True)
# Out:
# 'Blast'
