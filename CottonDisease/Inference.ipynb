# %%
import sys

# %%
sys.path.append(r'../HelperFunctions')

# %%
import DataHelper as dh
import InferenceHelper as ih

# %%
path_info = dh.getFileDirectory(fetchType='file')
# Out:
# Please enter the root directory of the file path -> C:\Users\user\Desktop\ML\PyTorch\Hackathon\Cotton-Disease\data\Cotton-Detection\train\curl_virus\curl_1.jpg

# %%
path_info
# Out:
# {'path': 'C:\\Users\\user\\Desktop\\ML\\PyTorch\\Hackathon\\Cotton-Disease\\data\\Cotton-Detection\\train\\curl_virus\\curl_1.jpg',
#  'type': 'file'}

# %%
img = ih.getTestImg(path=path_info['path'])

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=227x222 at 0x2120AB3BB50>

# %%
weights = 'CottonModelWeights.pth'
dictlabel = ['bacterial_blight', 'curl_virus', 'fussarium_wilt', 'healthy']

# %%
import AugHelper as ah

# %%
imgTransform = ah.getImageTransform(224)

# %%
imgTransform
# Out:
# Compose(
#     Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=None)
#     ToTensor()
#     Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
# )

# %%
from CottonModel import CottonTypeModel

# %%
model = CottonTypeModel()

# %%
model
# Out:
# CottonTypeModel(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=1600, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=4, bias=True)
# )

# %%
ih.inference(img_path=path_info['path'],model=model,weight_path=weights,dictlabel=dictlabel,transform=imgTransform,softmax=True)
# Out:
# 'curl_virus'
