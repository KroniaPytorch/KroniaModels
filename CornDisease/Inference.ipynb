# %%
import sys
sys.path.append(r'../HelperFunctions')

# %%
import DataHelper as dh
import AugHelper as ah
import InferenceHelper as ih
import ModelConfigHelper as mch

# %%
path_info = dh.getFileDirectory(fetchType='file')
path_info
# Out:
# Please enter the root directory of the file path -> C:\Users\user\Desktop\ML\PyTorch\Hackathon\Corn-Disease\Dataset\archive(5)\Corn Disease resized\Healthy corn\20200610_063438.jpg
# {'path': 'C:\\Users\\user\\Desktop\\ML\\PyTorch\\Hackathon\\Corn-Disease\\Dataset\\archive(5)\\Corn Disease resized\\Healthy corn\\20200610_063438.jpg',
#  'type': 'file'}

# %%
img = ih.getTestImg(path=path_info['path'])
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x1FC0AFBB820>

# %%
weights = 'CornDisease.pth'
dictlabel = ['Healthy corn', 'Infected']

# %%
imgTransform = ah.getImageTransform(227)

# %%
model = mch.getCustomizedPreTrainedModel('alexnet',len(dictlabel),feature_extract=False,preTrained=False)

# %%
ih.inference(img_path=path_info['path'],model=model,weight_path=weights,dictlabel=dictlabel,transform=imgTransform,softmax=False)
# Out:
# 'Healthy corn'
